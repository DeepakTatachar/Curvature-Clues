# %%
import os
import json
import logging
import numpy as np
from tqdm import tqdm
from utils.load_dataset import load_dataset

with open("./config.json") as f:
    config = json.load(f)

logger = logging.getLogger("")
dataset_name = 'cifar100'
arch = 'resnet18'
num_augs = 2

dataset = load_dataset(
    dataset=dataset_name,
    train_batch_size=128,
    test_batch_size=128,
    val_split=0.0,
    augment=False,
    shuffle=False,
    root_path=config['data_dir'],
    random_seed=0,
    mean=[0, 0, 0],
    std=[1, 1, 1],
    logger=logger,
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def get_scores_and_masks(seeds, dataset, method, num_augs):
    h = 0.001
    num_seeds = len(seeds)
    aug_scores_file_name = {
        'curv_zo' : "curvature_scores_zo_{}_{}_{}_{}_tid{}.pt",
        'curv' : "curvature_scores_{}_{}_{}_{}_tid{}.pt",
        'prob' : "prob_{}_{}_{}_tid{}.pt",
        'loss' : "losses_{}_{}_{}_tid{}.pt",
        'mentr' : "m_entropy_{}_{}_{}_tid{}.pt",
        'loss_g' : "loss_g_{}_{}_{}_tid{}.pt",
    }

    score_seeds_v_seed = np.zeros((num_augs, dataset.train_length, num_seeds))
    mask_seeds_v_seed = np.zeros((dataset.train_length, num_seeds))
    start_seed = seeds[0]
    for exp_idx in seeds:
        array_idx = exp_idx - start_seed
        augs = 1 if method == 'mentr' else num_augs
        for aug_idx in range(augs):
            if 'curv' in aug_scores_file_name[method]:
                file_name = aug_scores_file_name[method].format(dataset.name, arch, exp_idx, h, aug_idx)
            else:
                file_name = aug_scores_file_name[method].format(dataset.name, arch, exp_idx, aug_idx)

            absolute_file_name = os.path.join(config['precomputed_scores_dir'], dataset.name, file_name)
            scores = np.load(absolute_file_name)['data']
            score_seeds_v_seed[aug_idx, :, array_idx] = scores

        if dataset == 'imagenet':
            array = np.load(f'/path/imagenet-resnet50/{0.7}/{exp_idx}/aux_arrays.npz')
            mask_idxs = array['subsample_idx']
            mask_seeds_v_seed[mask_idxs, array_idx] = 1
        else:
            mask_idxs = np.load(os.path.join(config['subset_idxs_dir'], f"{exp_idx}.npy"))
            mask_seeds_v_seed[mask_idxs, array_idx] = 1

    return score_seeds_v_seed, mask_seeds_v_seed

def get_scores_and_masks_test(seeds, dataset, method, num_augs, order_type='top'):
    h = 0.001
    num_seeds = len(seeds)
    aug_scores_file_name = {
        'curv_zo' : "curvature_scores_zo_{}_{}_{}_{}_{}_{}_tid{}.pt",
        'prob' : "prob_{}_{}_{}_{}_{}_{}_tid{}.pt",
        'loss' : "losses_{}_{}_{}_{}_{}_{}_tid{}.pt",
    }

    score_seeds_v_seed = np.zeros((num_augs, dataset.train_length, num_seeds))
    mask_seeds_v_seed = np.zeros((dataset.train_length, num_seeds))
    for array_idx, (suffix, exp_idx)  in enumerate(seeds):
        augs = 1 if method == 'mentr' else num_augs
        for aug_idx in range(augs):
            file_name = aug_scores_file_name[method].format(
                dataset.name,
                arch, 
                exp_idx, 
                order_type, 
                suffix, 
                h, 
                aug_idx)

            absolute_file_name = os.path.join(
                config['precomputed_scores_dir'], 
                f'{dataset.name}_{order_type}', file_name)

            scores = np.load(absolute_file_name)['data']
            score_seeds_v_seed[aug_idx, :, array_idx] = scores

            score_seeds_v_seed[aug_idx, :, array_idx] = scores

        if dataset == 'imagenet':
            array = np.load(f'/path/imagenet-resnet50/{0.7}/{exp_idx}/aux_arrays.npz')
            mask_idxs = array['subsample_idx']
            mask_seeds_v_seed[mask_idxs, array_idx] = 1
        else:
            if order_type == 'top':
                mask_idxs = np.load(f'./dataset_idxs/cifar100/curvature_sorted.npy')[:suffix]
            else:
                mask_idxs = np.load(f'./dataset_idxs/cifar100/random_all.npy')[:suffix]
            mask_seeds_v_seed[mask_idxs, array_idx] = 1

    return score_seeds_v_seed, mask_seeds_v_seed

def get_score_dist_params(scores, masks, num_augs):
    means_in = []
    means_out = []
    var_in = []
    var_out = []
    for aug in range(num_augs):
        in_scores = np.where(masks == 1, scores[aug], np.NaN)
        out_scores = np.where(masks == 0, scores[aug], np.NaN)
        means_in.append(np.nanmean(in_scores, axis=1))
        means_out.append(np.nanmean(out_scores, axis=1))
        var_in.append(np.nanvar(in_scores, axis=1))
        var_out.append(np.nanvar(out_scores, axis=1))

    return {
        'means_in': np.row_stack(means_in),
        'means_out': np.row_stack(means_out),
        'var_in': np.row_stack(var_in),
        'var_out': np.row_stack(var_out)
    }

# %%
scores = {}
masks = {}
dist_params = {}
train_end_seed = 64
train_seeds = list(range(train_end_seed))
test_seeds = [train_end_seed]
eps = 1e-32

# %%
def log_err(x):
    return np.log(x + eps)

def logit_scale(x):
    x = x / (1 - x + eps)
    return log_err(x)

def nll(curv_score, mean, var):
    ll = - ( ( (curv_score - mean)**2) / (2 * (var ** 2) ) ) -0.5 * np.log(var ** 2) - 0.5 * np.log(2 * np.pi)
    return -ll

def likelihood(curv_score, mean, var):
    nll = - ( ( (curv_score - mean)**2) / (2 * (var ** 2) ) ) - 0.5 * np.log(var ** 2) - 0.5 * np.log(2 * np.pi)
    likelihood_val = np.exp(nll)
    return likelihood_val

def get_likelihood_ratio(test_scores, dist_params, num_augs, train_scores, train_masks):
    in_likelihood = np.zeros((test_scores.shape[1]))
    out_likelihood = np.zeros_like(in_likelihood)
    for aug in range(num_augs):
        test_score_aug = test_scores[aug, :, 0]
        in_likelihood += likelihood(
            test_score_aug, 
            dist_params['means_in'][aug], 
            dist_params['var_in'][aug] + eps)

        out_likelihood += likelihood(
            test_score_aug, 
            dist_params['means_out'][aug], 
            dist_params['var_out'][aug] + eps)

    likelihood_ratio = in_likelihood / (out_likelihood + eps)
    return likelihood_ratio

def get_nll_ratio(test_scores, dist_params, num_augs, train_scores, train_masks):
    in_likelihood = np.zeros((test_scores.shape[1]))
    out_likelihood = np.zeros_like(in_likelihood)
    for aug in range(num_augs):
        test_score_aug = test_scores[aug, :, 0]
        in_likelihood += nll(
            test_score_aug, 
            dist_params['means_in'][aug], 
            dist_params['var_in'][aug] + eps)

        out_likelihood += nll(
            test_score_aug, 
            dist_params['means_out'][aug], 
            dist_params['var_in'][aug] + eps)

    likelihood_ratio = in_likelihood - out_likelihood
    return -likelihood_ratio

def get_nll_ratio_c(test_scores, dist_params, num_augs, train_scores, train_masks):
    in_likelihood = np.zeros((test_scores.shape[1]))
    out_likelihood = np.zeros_like(in_likelihood)
    for aug in range(num_augs):
        test_score_aug = test_scores[aug, :, 0]
        in_likelihood += nll(
            test_score_aug, 
            dist_params['means_in'][aug], 
            1)

        out_likelihood += nll(
            test_score_aug, 
            dist_params['means_out'][aug], 
            1)

    likelihood_ratio = in_likelihood - out_likelihood
    return -likelihood_ratio

def get_identity(test_scores, dist_params, num_augs, train_scores, train_masks):
    return -test_scores[0]

def get_mast(test_scores, dist_params, num_augs, train_scores, train_masks):
    aug = 0
    threshold = (dist_params['means_in'][aug] +  dist_params['means_out'][aug]) / 2 
    return -(test_scores[aug, :, 0] - threshold)

def get_mast_offline(test_scores, dist_params, num_augs, train_scores, train_masks):
    aug = 0
    threshold = dist_params['means_out'][aug]
    return -(test_scores[aug, :, 0] - threshold)

def get_ye_et_el_attack_r(test_scores, dist_params, num_augs, train_scores, train_masks):
    aug = 0
    alpha = 1e-4
    out_scores = np.where(train_masks == 0, train_scores[aug], np.NaN)
    threshold = np.nanpercentile(out_scores, alpha * 100, axis=1)
    return -(test_scores[aug, :, 0] - threshold)

def get_class_based(test_scores, dist_params, num_augs, train_scores, train_masks):
    # This is handled during roc calculations
    return -test_scores[0, :, 0]

def get_loss_count(test_scores, dist_params, num_augs, train_scores, train_masks):
    in_scores = np.where(train_masks == 1, train_scores[0], np.NaN)
    threshold = np.nanmean(in_scores)
    pred = (test_scores[:, :, 0] < threshold).sum(0) / num_augs
    return pred

methods = [
    ('curv_zo', log_err, get_nll_ratio, 'Curv ZO NLL', num_augs, train_seeds), 
    ('curv_zo', log_err, get_likelihood_ratio, 'Curv ZO LR', num_augs, train_seeds), 
    ('prob', logit_scale, get_likelihood_ratio, 'Carlini et al.', num_augs, train_seeds),
    ('loss', lambda x: x, get_identity, 'Yeom et al.', 1, [0]),
]

# %%
for info_type, score_func, _, method_name, augs, seeds in methods:
    if method_name in scores:
        continue
    
    score, mask = get_scores_and_masks(
        seeds=seeds, 
        dataset=dataset,
        method=info_type,
        num_augs=augs)

    score = score_func(score)
    params = get_score_dist_params(score, mask, augs)
    scores[method_name] = score
    masks[method_name] = mask
    dist_params[method_name] = params
# Out:
# /tmp/ipykernel_28371/3153369307.py:92: RuntimeWarning: Mean of empty slice
#   means_in.append(np.nanmean(in_scores, axis=1))
# /tmp/ipykernel_28371/3153369307.py:93: RuntimeWarning: Mean of empty slice
#   means_out.append(np.nanmean(out_scores, axis=1))
# /tmp/ipykernel_28371/3153369307.py:94: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var_in.append(np.nanvar(in_scores, axis=1))
# /tmp/ipykernel_28371/3153369307.py:95: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var_out.append(np.nanvar(out_scores, axis=1))

# %%
from sklearn.metrics import roc_auc_score, roc_curve, balanced_accuracy_score

def find_tpr_at_fpr(tpr, fpr, target_fpr=1e-1):
    """
    Finds the TPR when FPR equals target_fpr using interpolation.

    Parameters:
    tpr (array): Array of true positive rates.
    fpr (array): Array of false positive rates.
    target_fpr (float): The target false positive rate. Default is 1e-1.

    Returns:
    float: Interpolated TPR at the target FPR.
    """
    # Ensure the arrays are numpy arrays
    tpr = np.array(tpr)
    fpr = np.array(fpr)

    # Use numpy's interpolation function
    tpr_at_target_fpr = np.interp(target_fpr, fpr, tpr)
    return tpr_at_target_fpr

def get_metrics_for_method(method_name, dataset, y_true, y_pred):
    if method_name == 'Song et al.':
        labels_file_name = os.path.join(
            config['precomputed_scores_dir'], 
            dataset.name, 
            f"true_labels_cifar100_{train_end_seed}.pt")
        labels = np.load(labels_file_name)['data']
        
        auc = 0 
        n_classes = dataset.num_classes
        balanced_accuracy = 0
        for label in range(n_classes):
            indices = np.where(labels == label)[0]
            # Compute ROC curve for each class
            fpr, tpr, thr = roc_curve(y_true[indices], y_pred[indices])
            auc += roc_auc_score(y_true, y_pred)
            
            # Find the optimal threshold: where the sum of FPR and TPR is closest to 1
            optimal_idx = np.argmin(np.abs(fpr + tpr - 1))
            optimal_threshold = thr[optimal_idx]
            # Binarize predictions based on the optimal threshold
            y_pred_binarized = (y_pred >= optimal_threshold).astype(int)

            # Calculate Balanced Accuracy
            balanced_accuracy += balanced_accuracy_score(y_true, y_pred_binarized)
        
        auc = auc / n_classes
        balanced_accuracy = balanced_accuracy / n_classes

    else:
        fpr, tpr, thr = roc_curve(y_true, y_pred, pos_label=1)
        auc = roc_auc_score(y_true, y_pred)
        tpr1p_base = find_tpr_at_fpr(tpr, fpr, target_fpr=1e-2)
        tpr01p_base = find_tpr_at_fpr(tpr, fpr, target_fpr=1e-3)

        # Find the optimal threshold: where the sum of FPR and TPR is closest to 1
        # "Balanced accuracy is symmetric. That is, the metric
        # assigns equal cost to false-positives and to false-negatives."
        # - LiRA https://arxiv.org/pdf/2112.03570.pdf
        optimal_idx = np.argmin(np.abs(fpr + tpr - 1))
        optimal_threshold = thr[optimal_idx]

        # if auc < 0.5:
        #     # Binarize predictions based on the optimal threshold
        #     auc = 1 - auc
        #     y_pred_binarized = (y_pred <= optimal_threshold).astype(int)
        # else:
        # Binarize predictions based on the optimal threshold
        y_pred_binarized = (y_pred >= optimal_threshold).astype(int)

        # Calculate Balanced Accuracy
        balanced_accuracy = balanced_accuracy_score(y_true, y_pred_binarized)

    return auc, balanced_accuracy, tpr1p_base, tpr01p_base

# %%
from sklearn.metrics import roc_auc_score, roc_curve, balanced_accuracy_score
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['ieee', 'science', 'grid'])

accs_for_pu_trade_off = {}
bal_acc_for_pu_trade_off = {}
tpr1p_trade_off = {}
tpr01p_trade_off = {}
plot_auroc = {}
plot_acc = {}
plot_m = {}
order_types = ['top']
for order_type in order_types:
    accs_for_pu_trade_off[order_type] = {}
    bal_acc_for_pu_trade_off[order_type] = {}
    plot_auroc[order_type] = {}
    plot_acc[order_type] = {}
    plot_m[order_type] = {}
    tpr1p_trade_off[order_type] = {}
    tpr01p_trade_off[order_type] = {}
    for info_type, score_func, _, method_name, augs, seeds in methods:
        plot_auroc[order_type][method_name] = []
        plot_acc[order_type][method_name] = []
        plot_m[order_type][method_name] = []
        bal_acc_for_pu_trade_off[order_type][method_name] = {}
        tpr1p_trade_off[order_type][method_name] = {}
        tpr01p_trade_off[order_type][method_name] = {}

for order_type in order_types:
    test_scores = {}
    test_masks = {}
    test_exps = [0, 1, 2, 3, 4, 5]
    test_len = [500, 2000, 6000, 10000, 12000, 15000, 18000, 20000, 25000, 30000, 35000, 45000]
    test_seeds = []
    for t_len in test_len:
        for t_exp_idx in test_exps:
            test_seeds.append((t_len, t_exp_idx))

    for info_type, score_func, _, method_name, augs, _ in methods:
        test_score, test_mask = get_scores_and_masks_test(
            seeds=test_seeds, 
            dataset=dataset,
            method=info_type,
            num_augs=augs,
            order_type=order_type)

        test_scores[method_name] = score_func(test_score)
        test_masks[method_name] = test_mask

    
    for _, (info_type, _, pred_func, method_name, augs, _) in enumerate(methods):
        aurocs = {}
        accs = {}
        m = {}
        tpr1p = {}
        tpr01p = {}

        for t_seed_idx, (train_len, seed) in enumerate(test_seeds):
            y_pred = pred_func(
                test_scores[method_name][..., t_seed_idx, np.newaxis],
                dist_params[method_name],
                augs,
                scores[method_name],
                masks[method_name])

            y_true = test_masks[method_name][..., t_seed_idx, np.newaxis] #[:1000]
            auc, balanced_accuracy, tp1p, tp01p = get_metrics_for_method(method_name, dataset, y_true, y_pred)
            print(f"AUC {method_name} {train_len}: {auc*100:.2f}, Acc {balanced_accuracy * 100:.2f}")
            print(f"TPR 1% {method_name} {train_len}: {tp1p*100:.2f}, TPR 0.1% {tp01p * 100:.2f}")
            
            if train_len in m:
                accs[train_len].append(balanced_accuracy)
                aurocs[train_len].append(auc)
                m[train_len].append(train_len)
                tpr1p[train_len].append(tp1p)
                tpr01p[train_len].append(tp01p)
            else:
                accs[train_len] = [balanced_accuracy]
                aurocs[train_len] = [auc]
                m[train_len] = [train_len]                
                tpr1p[train_len] = [tp1p]
                tpr01p[train_len] = [tp01p]

        for key in m.keys():
            plot_acc[order_type][method_name].append(np.array(accs[key]).mean())
            auroc = np.array(aurocs[key]).mean()
            plot_auroc[order_type][method_name].append(auroc)
            plot_m[order_type][method_name].append(np.array(m[key]).mean())
            if key in accs_for_pu_trade_off[order_type]:
                accs_for_pu_trade_off[order_type][key] += [(aurocs[key], method_name)]
                bal_acc_for_pu_trade_off[order_type][key] += [(accs[key], method_name)]
                tpr1p_trade_off[order_type][key] += [(tpr1p[key], method_name)]
                tpr01p_trade_off[order_type][key] += [(tpr01p[key], method_name)]
            else:
                accs_for_pu_trade_off[order_type][key] = [(aurocs[key], method_name)]
                bal_acc_for_pu_trade_off[order_type][key] = [(accs[key], method_name)]
                tpr1p_trade_off[order_type][key] = [(tpr1p[key], method_name)]
                tpr01p_trade_off[order_type][key] = [(tpr01p[key], method_name)]
# Out:
# AUC Curv ZO NLL 500: 70.73, Acc 69.59
# TPR 1% Curv ZO NLL 500: 0.80, TPR 0.1% 0.80
# AUC Curv ZO NLL 500: 90.41, Acc 86.55
# TPR 1% Curv ZO NLL 500: 0.80, TPR 0.1% 0.80
# AUC Curv ZO NLL 500: 91.15, Acc 86.98
# TPR 1% Curv ZO NLL 500: 1.00, TPR 0.1% 1.00
# TPR 1% Curv ZO NLL 45000: 56.11, TPR 0.1% 30.94
# AUC Curv ZO LR 500: 58.10, Acc 58.62
# TPR 1% Curv ZO LR 500: 0.40, TPR 0.1% 0.40
# AUC Curv ZO LR 500: 83.28, Acc 80.99
# TPR 1% Curv ZO LR 500: 0.20, TPR 0.1% 0.20
# AUC Curv ZO LR 500: 85.36, Acc 82.63
# TPR 1% Curv ZO LR 500: 0.60, TPR 0.1% 0.20
# AUC Curv ZO LR 500: 82.79, Acc 80.43
# TPR 1% Curv ZO LR 500: 0.40, TPR 0.1% 0.20
# AUC Curv ZO LR 500: 83.84, Acc 81.40
# TPR 1% Curv ZO LR 500: 0.60, TPR 0.1% 0.40
# AUC Curv ZO LR 500: 81.70, Acc 79.18
# TPR 1% Curv ZO LR 500: 0.60, TPR 0.1% 0.20
# AUC Curv ZO LR 2000: 63.29, Acc 63.80
# TPR 1% Curv ZO LR 2000: 0.05, TPR 0.1% 0.05
# AUC Curv ZO LR 2000: 82.50, Acc 80.70
# TPR 1% Curv ZO LR 2000: 0.15, TPR 0.1% 0.10
# AUC Curv ZO LR 2000: 82.34, Acc 80.53
# TPR 1% Curv ZO LR 2000: 0.15, TPR 0.1% 0.10
# AUC Curv ZO LR 2000: 81.26, Acc 79.70
# TPR 1% Curv ZO LR 2000: 0.20, TPR 0.1% 0.10
# AUC Curv ZO LR 2000: 81.42, Acc 79.79
# TPR 1% Curv ZO LR 2000: 0.05, TPR 0.1% 0.05
# AUC Curv ZO LR 2000: 83.07, Acc 81.29
# TPR 1% Curv ZO LR 2000: 0.10, TPR 0.1% 0.05
# AUC Curv ZO LR 6000: 63.30, Acc 65.90
# TPR 1% Curv ZO LR 6000: 0.02, TPR 0.1% 0.02
# AUC Curv ZO LR 6000: 79.61, Acc 79.15
# TPR 1% Curv ZO LR 6000: 0.05, TPR 0.1% 0.03
# AUC Curv ZO LR 6000: 79.71, Acc 78.98
# TPR 1% Curv ZO LR 6000: 0.20, TPR 0.1% 0.03
# AUC Curv ZO LR 6000: 79.94, Acc 79.38
# TPR 1% Curv ZO LR 6000: 0.05, TPR 0.1% 0.02
# AUC Curv ZO LR 6000: 79.37, Acc 78.75
# TPR 1% Curv ZO LR 6000: 0.22, TPR 0.1% 0.03
# AUC Curv ZO LR 6000: 63.08, Acc 65.81
# TPR 1% Curv ZO LR 6000: 0.02, TPR 0.1% 0.02
# AUC Curv ZO LR 10000: 80.35, Acc 78.35
# TPR 1% Curv ZO LR 10000: 1.11, TPR 0.1% 0.03
# AUC Curv ZO LR 10000: 81.60, Acc 79.56
# TPR 1% Curv ZO LR 10000: 0.35, TPR 0.1% 0.03
# AUC Curv ZO LR 10000: 82.53, Acc 80.26
# TPR 1% Curv ZO LR 10000: 0.35, TPR 0.1% 0.03
# AUC Curv ZO LR 10000: 82.33, Acc 80.07
# TPR 1% Curv ZO LR 10000: 0.29, TPR 0.1% 0.02
# AUC Curv ZO LR 10000: 81.54, Acc 79.64
# TPR 1% Curv ZO LR 10000: 0.42, TPR 0.1% 0.03
# AUC Curv ZO LR 10000: 82.03, Acc 79.75
# TPR 1% Curv ZO LR 10000: 0.34, TPR 0.1% 0.03
# AUC Curv ZO LR 12000: 67.27, Acc 69.03
# TPR 1% Curv ZO LR 12000: 0.05, TPR 0.1% 0.05
# AUC Curv ZO LR 12000: 67.47, Acc 69.29
# TPR 1% Curv ZO LR 12000: 0.06, TPR 0.1% 0.05
# AUC Curv ZO LR 12000: 80.97, Acc 78.54
# TPR 1% Curv ZO LR 12000: 0.17, TPR 0.1% 0.03
# AUC Curv ZO LR 12000: 81.75, Acc 79.19
# TPR 1% Curv ZO LR 12000: 0.12, TPR 0.1% 0.05
# AUC Curv ZO LR 12000: 81.12, Acc 78.75
# TPR 1% Curv ZO LR 12000: 0.13, TPR 0.1% 0.05
# AUC Curv ZO LR 12000: 80.62, Acc 78.63
# TPR 1% Curv ZO LR 12000: 0.10, TPR 0.1% 0.05
# AUC Curv ZO LR 15000: 70.19, Acc 71.21
# TPR 1% Curv ZO LR 15000: 0.24, TPR 0.1% 0.18
# AUC Curv ZO LR 15000: 65.58, Acc 67.77
# TPR 1% Curv ZO LR 15000: 0.17, TPR 0.1% 0.17
# AUC Curv ZO LR 15000: 74.28, Acc 73.52
# TPR 1% Curv ZO LR 15000: 0.35, TPR 0.1% 0.18
# AUC Curv ZO LR 15000: 84.02, Acc 79.10
# TPR 1% Curv ZO LR 15000: 0.43, TPR 0.1% 0.21
# AUC Curv ZO LR 15000: 84.09, Acc 79.20
# TPR 1% Curv ZO LR 15000: 0.58, TPR 0.1% 0.25
# AUC Curv ZO LR 15000: 83.38, Acc 78.89
# TPR 1% Curv ZO LR 15000: 0.37, TPR 0.1% 0.23
# AUC Curv ZO LR 18000: 79.73, Acc 77.16
# TPR 1% Curv ZO LR 18000: 0.72, TPR 0.1% 0.41
# AUC Curv ZO LR 18000: 81.99, Acc 77.99
# TPR 1% Curv ZO LR 18000: 0.97, TPR 0.1% 0.58
# AUC Curv ZO LR 18000: 78.57, Acc 75.87
# TPR 1% Curv ZO LR 18000: 1.40, TPR 0.1% 0.46
# AUC Curv ZO LR 18000: 80.51, Acc 77.44
# TPR 1% Curv ZO LR 18000: 0.80, TPR 0.1% 0.45
# AUC Curv ZO LR 18000: 86.69, Acc 79.31
# TPR 1% Curv ZO LR 18000: 1.12, TPR 0.1% 0.59
# AUC Curv ZO LR 18000: 85.92, Acc 79.22
# TPR 1% Curv ZO LR 18000: 1.02, TPR 0.1% 0.53
# AUC Curv ZO LR 20000: 86.81, Acc 81.05
# TPR 1% Curv ZO LR 20000: 5.09, TPR 0.1% 1.80
# AUC Curv ZO LR 20000: 87.48, Acc 79.84
# TPR 1% Curv ZO LR 20000: 1.82, TPR 0.1% 0.80
# AUC Curv ZO LR 20000: 88.64, Acc 80.50
# TPR 1% Curv ZO LR 20000: 3.94, TPR 0.1% 1.10
# AUC Curv ZO LR 20000: 88.55, Acc 80.48
# TPR 1% Curv ZO LR 20000: 4.00, TPR 0.1% 1.15
# AUC Curv ZO LR 20000: 88.31, Acc 80.31
# TPR 1% Curv ZO LR 20000: 3.06, TPR 0.1% 1.07
# AUC Curv ZO LR 20000: 88.55, Acc 80.53
# TPR 1% Curv ZO LR 20000: 5.50, TPR 0.1% 1.23
# AUC Curv ZO LR 25000: 90.20, Acc 82.35
# TPR 1% Curv ZO LR 25000: 7.82, TPR 0.1% 3.03
# AUC Curv ZO LR 25000: 88.84, Acc 81.20
# TPR 1% Curv ZO LR 25000: 3.83, TPR 0.1% 2.25
# AUC Curv ZO LR 25000: 90.06, Acc 82.06
# TPR 1% Curv ZO LR 25000: 7.76, TPR 0.1% 2.99
# AUC Curv ZO LR 25000: 90.07, Acc 81.76
# TPR 1% Curv ZO LR 25000: 6.36, TPR 0.1% 2.51
# AUC Curv ZO LR 25000: 90.43, Acc 81.76
# TPR 1% Curv ZO LR 25000: 5.95, TPR 0.1% 2.44
# AUC Curv ZO LR 25000: 89.05, Acc 81.88
# TPR 1% Curv ZO LR 25000: 5.62, TPR 0.1% 2.51
# AUC Curv ZO LR 30000: 91.21, Acc 83.79
# TPR 1% Curv ZO LR 30000: 11.10, TPR 0.1% 4.71
# AUC Curv ZO LR 30000: 92.09, Acc 83.33
# TPR 1% Curv ZO LR 30000: 9.01, TPR 0.1% 3.74
# AUC Curv ZO LR 30000: 91.73, Acc 83.48
# TPR 1% Curv ZO LR 30000: 10.18, TPR 0.1% 4.21
# AUC Curv ZO LR 30000: 91.94, Acc 83.64
# TPR 1% Curv ZO LR 30000: 10.77, TPR 0.1% 4.21
# AUC Curv ZO LR 30000: 90.01, Acc 83.34
# TPR 1% Curv ZO LR 30000: 9.26, TPR 0.1% 5.23
# AUC Curv ZO LR 30000: 92.88, Acc 83.92
# TPR 1% Curv ZO LR 30000: 10.93, TPR 0.1% 4.83
# AUC Curv ZO LR 35000: 88.72, Acc 83.54
# TPR 1% Curv ZO LR 35000: 10.79, TPR 0.1% 7.08
# AUC Curv ZO LR 35000: 93.89, Acc 85.40
# TPR 1% Curv ZO LR 35000: 15.30, TPR 0.1% 7.55
# AUC Curv ZO LR 35000: 92.83, Acc 85.22
# TPR 1% Curv ZO LR 35000: 14.07, TPR 0.1% 8.01
# AUC Curv ZO LR 35000: 91.39, Acc 84.88
# TPR 1% Curv ZO LR 35000: 13.29, TPR 0.1% 7.82
# AUC Curv ZO LR 35000: 91.52, Acc 85.13
# TPR 1% Curv ZO LR 35000: 12.93, TPR 0.1% 7.18
# AUC Curv ZO LR 35000: 92.31, Acc 85.12
# TPR 1% Curv ZO LR 35000: 14.12, TPR 0.1% 7.65
# AUC Curv ZO LR 45000: 77.19, Acc 71.67
# TPR 1% Curv ZO LR 45000: 14.71, TPR 0.1% 12.89
# AUC Curv ZO LR 45000: 81.97, Acc 76.80
# TPR 1% Curv ZO LR 45000: 16.54, TPR 0.1% 13.47
# AUC Curv ZO LR 45000: 81.41, Acc 76.24
# TPR 1% Curv ZO LR 45000: 16.37, TPR 0.1% 11.81
# AUC Curv ZO LR 45000: 86.41, Acc 81.60
# TPR 1% Curv ZO LR 45000: 18.42, TPR 0.1% 12.28
# AUC Curv ZO LR 45000: 85.76, Acc 80.72
# TPR 1% Curv ZO LR 45000: 18.26, TPR 0.1% 14.45
# AUC Curv ZO LR 45000: 84.15, Acc 78.88
# TPR 1% Curv ZO LR 45000: 17.22, TPR 0.1% 13.57
# AUC Carlini et al. 500: 79.90, Acc 77.60
# TPR 1% Carlini et al. 500: 0.20, TPR 0.1% 0.20
# AUC Carlini et al. 500: 77.15, Acc 75.41
# TPR 1% Carlini et al. 500: 0.20, TPR 0.1% 0.20
# AUC Carlini et al. 500: 76.87, Acc 75.21
# TPR 1% Carlini et al. 500: 0.20, TPR 0.1% 0.20
# AUC Carlini et al. 500: 78.33, Acc 76.62
# TPR 1% Carlini et al. 500: 0.40, TPR 0.1% 0.40
# AUC Carlini et al. 500: 76.54, Acc 74.60
# TPR 1% Carlini et al. 500: 0.60, TPR 0.1% 0.60
# AUC Carlini et al. 500: 74.57, Acc 73.01
# TPR 1% Carlini et al. 500: 0.40, TPR 0.1% 0.40
# AUC Carlini et al. 2000: 79.03, Acc 77.80
# TPR 1% Carlini et al. 2000: 0.30, TPR 0.1% 0.25
# AUC Carlini et al. 2000: 77.26, Acc 76.29
# TPR 1% Carlini et al. 2000: 0.30, TPR 0.1% 0.30
# AUC Carlini et al. 2000: 77.09, Acc 76.20
# TPR 1% Carlini et al. 2000: 0.20, TPR 0.1% 0.20
# AUC Carlini et al. 2000: 77.48, Acc 76.44
# TPR 1% Carlini et al. 2000: 0.30, TPR 0.1% 0.20
# AUC Carlini et al. 2000: 77.18, Acc 76.24
# TPR 1% Carlini et al. 2000: 0.25, TPR 0.1% 0.25
# AUC Carlini et al. 2000: 77.49, Acc 76.36
# TPR 1% Carlini et al. 2000: 0.15, TPR 0.1% 0.15
# AUC Carlini et al. 6000: 80.88, Acc 78.58
# TPR 1% Carlini et al. 6000: 5.08, TPR 0.1% 0.03
# AUC Carlini et al. 6000: 81.02, Acc 78.73
# TPR 1% Carlini et al. 6000: 4.12, TPR 0.1% 0.00
# AUC Carlini et al. 6000: 79.17, Acc 77.14
# TPR 1% Carlini et al. 6000: 2.12, TPR 0.1% 0.05
# AUC Carlini et al. 6000: 81.12, Acc 78.69
# TPR 1% Carlini et al. 6000: 4.98, TPR 0.1% 0.00
# AUC Carlini et al. 6000: 79.59, Acc 77.51
# TPR 1% Carlini et al. 6000: 3.58, TPR 0.1% 0.03
# AUC Carlini et al. 6000: 81.07, Acc 78.81
# TPR 1% Carlini et al. 6000: 4.63, TPR 0.1% 0.00
# AUC Carlini et al. 10000: 79.33, Acc 76.43
# TPR 1% Carlini et al. 10000: 5.57, TPR 0.1% 0.56
# AUC Carlini et al. 10000: 80.50, Acc 77.88
# TPR 1% Carlini et al. 10000: 5.27, TPR 0.1% 0.16
# AUC Carlini et al. 10000: 80.41, Acc 77.82
# TPR 1% Carlini et al. 10000: 5.13, TPR 0.1% 0.11
# AUC Carlini et al. 10000: 80.21, Acc 77.59
# TPR 1% Carlini et al. 10000: 5.42, TPR 0.1% 0.11
# AUC Carlini et al. 10000: 79.93, Acc 77.36
# TPR 1% Carlini et al. 20000: 10.75, TPR 0.1% 1.06
# AUC Carlini et al. 20000: 85.55, Acc 80.85
# TPR 1% Carlini et al. 20000: 12.04, TPR 0.1% 1.42
# AUC Carlini et al. 25000: 87.22, Acc 82.19
# TPR 1% Carlini et al. 25000: 15.20, TPR 0.1% 2.90
# AUC Carlini et al. 25000: 90.49, Acc 85.79
# TPR 1% Carlini et al. 25000: 21.34, TPR 0.1% 3.88
# AUC Carlini et al. 25000: 87.37, Acc 82.28
# TPR 1% Carlini et al. 25000: 14.86, TPR 0.1% 2.59
# AUC Carlini et al. 25000: 87.73, Acc 83.04
# TPR 1% Carlini et al. 25000: 13.76, TPR 0.1% 2.48
# AUC Carlini et al. 25000: 89.40, Acc 84.61
# TPR 1% Carlini et al. 25000: 19.81, TPR 0.1% 5.72
# AUC Carlini et al. 25000: 86.67, Acc 81.83
# TPR 1% Carlini et al. 25000: 13.74, TPR 0.1% 2.64
# AUC Carlini et al. 30000: 88.71, Acc 83.58
# TPR 1% Carlini et al. 30000: 19.06, TPR 0.1% 4.21
# AUC Carlini et al. 30000: 91.52, Acc 86.69
# TPR 1% Carlini et al. 30000: 26.28, TPR 0.1% 6.19
# AUC Carlini et al. 30000: 89.41, Acc 84.63
# TPR 1% Carlini et al. 30000: 16.77, TPR 0.1% 3.89
# AUC Carlini et al. 30000: 90.04, Acc 84.95
# TPR 1% Carlini et al. 30000: 21.74, TPR 0.1% 6.03
# AUC Carlini et al. 30000: 88.25, Acc 83.09
# TPR 1% Carlini et al. 30000: 17.14, TPR 0.1% 3.92
# AUC Carlini et al. 30000: 91.78, Acc 86.87
# TPR 1% Carlini et al. 30000: 27.38, TPR 0.1% 5.95
# AUC Carlini et al. 35000: 89.61, Acc 84.34
# TPR 1% Carlini et al. 35000: 21.92, TPR 0.1% 7.74
# AUC Carlini et al. 35000: 92.96, Acc 88.23
# TPR 1% Carlini et al. 35000: 34.09, TPR 0.1% 10.20
# AUC Carlini et al. 35000: 91.37, Acc 86.22
# TPR 1% Carlini et al. 35000: 26.47, TPR 0.1% 7.03
# AUC Carlini et al. 35000: 89.79, Acc 84.47
# TPR 1% Carlini et al. 35000: 22.23, TPR 0.1% 7.32
# AUC Carlini et al. 35000: 89.76, Acc 84.57
# TPR 1% Carlini et al. 35000: 22.15, TPR 0.1% 6.83
# AUC Carlini et al. 35000: 90.85, Acc 85.51
# TPR 1% Carlini et al. 35000: 25.10, TPR 0.1% 8.22
# AUC Carlini et al. 45000: 91.17, Acc 85.49
# TPR 1% Carlini et al. 45000: 30.05, TPR 0.1% 8.37
# AUC Carlini et al. 45000: 90.85, Acc 85.12
# TPR 1% Carlini et al. 45000: 26.53, TPR 0.1% 9.94
# AUC Carlini et al. 45000: 90.88, Acc 85.36
# TPR 1% Carlini et al. 45000: 26.77, TPR 0.1% 11.44
# AUC Carlini et al. 45000: 90.72, Acc 85.18
# TPR 1% Carlini et al. 45000: 25.44, TPR 0.1% 7.94
# AUC Carlini et al. 45000: 90.83, Acc 85.40
# TPR 1% Carlini et al. 45000: 25.61, TPR 0.1% 10.29
# AUC Carlini et al. 45000: 91.00, Acc 85.44
# TPR 1% Carlini et al. 45000: 27.62, TPR 0.1% 13.05
# AUC Yeom et al. 500: 98.74, Acc 96.37
# TPR 1% Yeom et al. 500: 51.40, TPR 0.1% 9.23
# AUC Yeom et al. 500: 98.69, Acc 96.57
# TPR 1% Yeom et al. 500: 47.80, TPR 0.1% 2.78
# AUC Yeom et al. 500: 98.84, Acc 97.18
# TPR 1% Yeom et al. 500: 47.60, TPR 0.1% 6.03
# AUC Yeom et al. 500: 98.66, Acc 96.45
# TPR 1% Yeom et al. 500: 48.60, TPR 0.1% 4.99
# AUC Yeom et al. 500: 98.64, Acc 96.65
# TPR 1% Yeom et al. 500: 44.50, TPR 0.1% 3.15
# AUC Yeom et al. 500: 98.59, Acc 96.75
# TPR 1% Yeom et al. 500: 39.60, TPR 0.1% 3.54
# AUC Yeom et al. 2000: 98.31, Acc 95.35
# TPR 1% Yeom et al. 2000: 42.30, TPR 0.1% 6.40
# AUC Yeom et al. 2000: 97.96, Acc 95.10
# TPR 1% Yeom et al. 2000: 31.40, TPR 0.1% 5.07
# AUC Yeom et al. 2000: 98.06, Acc 95.14
# TPR 1% Yeom et al. 2000: 33.03, TPR 0.1% 5.84
# AUC Yeom et al. 2000: 98.06, Acc 95.05
# TPR 1% Yeom et al. 2000: 36.18, TPR 0.1% 6.24
# AUC Yeom et al. 2000: 98.04, Acc 95.15
# TPR 1% Yeom et al. 2000: 34.70, TPR 0.1% 4.88
# AUC Yeom et al. 2000: 97.94, Acc 95.05
# TPR 1% Yeom et al. 2000: 30.05, TPR 0.1% 4.47
# AUC Yeom et al. 6000: 97.47, Acc 93.77
# TPR 1% Yeom et al. 6000: 29.92, TPR 0.1% 5.60
# AUC Yeom et al. 6000: 97.52, Acc 93.94
# TPR 1% Yeom et al. 6000: 29.80, TPR 0.1% 4.82
# AUC Yeom et al. 6000: 97.38, Acc 93.47
# TPR 1% Yeom et al. 6000: 30.27, TPR 0.1% 5.76
# AUC Yeom et al. 6000: 97.48, Acc 93.95
# TPR 1% Yeom et al. 6000: 30.11, TPR 0.1% 5.68
# AUC Yeom et al. 6000: 97.30, Acc 93.17
# TPR 1% Yeom et al. 6000: 30.77, TPR 0.1% 5.76
# AUC Yeom et al. 6000: 97.52, Acc 93.86
# TPR 1% Yeom et al. 6000: 30.49, TPR 0.1% 5.43
# AUC Yeom et al. 10000: 97.41, Acc 92.62
# TPR 1% Yeom et al. 10000: 38.70, TPR 0.1% 7.66
# AUC Yeom et al. 10000: 96.94, Acc 91.93
# TPR 1% Yeom et al. 10000: 32.96, TPR 0.1% 8.15
# AUC Yeom et al. 10000: 96.85, Acc 91.74
# TPR 1% Yeom et al. 10000: 31.54, TPR 0.1% 8.28
# AUC Yeom et al. 10000: 96.82, Acc 91.68
# TPR 1% Yeom et al. 10000: 31.80, TPR 0.1% 7.98
# AUC Yeom et al. 10000: 96.88, Acc 91.75
# TPR 1% Yeom et al. 10000: 32.16, TPR 0.1% 8.30
# AUC Yeom et al. 10000: 96.92, Acc 91.80
# TPR 1% Yeom et al. 10000: 34.08, TPR 0.1% 9.84
# AUC Yeom et al. 12000: 97.62, Acc 93.51
# TPR 1% Yeom et al. 12000: 35.67, TPR 0.1% 7.40
# AUC Yeom et al. 12000: 97.63, Acc 93.62
# TPR 1% Yeom et al. 12000: 34.73, TPR 0.1% 8.37
# AUC Yeom et al. 12000: 97.47, Acc 93.04
# TPR 1% Yeom et al. 12000: 37.65, TPR 0.1% 9.41
# AUC Yeom et al. 12000: 97.76, Acc 93.90
# TPR 1% Yeom et al. 12000: 37.78, TPR 0.1% 8.75
# AUC Yeom et al. 12000: 97.52, Acc 93.24
# TPR 1% Yeom et al. 12000: 36.60, TPR 0.1% 7.92
# AUC Yeom et al. 12000: 97.65, Acc 93.62
# TPR 1% Yeom et al. 12000: 35.74, TPR 0.1% 7.81
# AUC Yeom et al. 15000: 97.80, Acc 93.96
# TPR 1% Yeom et al. 15000: 38.69, TPR 0.1% 9.03
# AUC Yeom et al. 15000: 98.04, Acc 94.67
# TPR 1% Yeom et al. 15000: 38.15, TPR 0.1% 7.97
# AUC Yeom et al. 15000: 97.60, Acc 93.11
# TPR 1% Yeom et al. 15000: 40.69, TPR 0.1% 11.20
# AUC Yeom et al. 15000: 97.79, Acc 93.71
# TPR 1% Yeom et al. 15000: 39.65, TPR 0.1% 12.01
# AUC Yeom et al. 15000: 97.69, Acc 93.31
# TPR 1% Yeom et al. 15000: 41.82, TPR 0.1% 11.64
# AUC Yeom et al. 15000: 97.84, Acc 94.09
# TPR 1% Yeom et al. 15000: 38.44, TPR 0.1% 8.96
# AUC Yeom et al. 18000: 98.13, Acc 94.45
# TPR 1% Yeom et al. 18000: 44.43, TPR 0.1% 11.01
# AUC Yeom et al. 18000: 97.93, Acc 93.68
# TPR 1% Yeom et al. 18000: 44.24, TPR 0.1% 12.68
# AUC Yeom et al. 18000: 97.64, Acc 92.90
# TPR 1% Yeom et al. 18000: 43.83, TPR 0.1% 11.62
# AUC Yeom et al. 18000: 98.04, Acc 94.12
# TPR 1% Yeom et al. 18000: 44.22, TPR 0.1% 11.81
# AUC Yeom et al. 18000: 97.90, Acc 94.03
# TPR 1% Yeom et al. 18000: 40.88, TPR 0.1% 11.87
# AUC Yeom et al. 18000: 98.04, Acc 94.12
# TPR 1% Yeom et al. 18000: 44.49, TPR 0.1% 12.81
# AUC Yeom et al. 20000: 98.04, Acc 93.66
# TPR 1% Yeom et al. 20000: 49.24, TPR 0.1% 12.50
# AUC Yeom et al. 20000: 98.17, Acc 94.42
# TPR 1% Yeom et al. 20000: 45.44, TPR 0.1% 13.70
# AUC Yeom et al. 20000: 98.01, Acc 93.76
# TPR 1% Yeom et al. 20000: 44.75, TPR 0.1% 12.53
# AUC Yeom et al. 20000: 97.54, Acc 92.49
# TPR 1% Yeom et al. 20000: 44.25, TPR 0.1% 14.29
# AUC Yeom et al. 20000: 97.57, Acc 92.52
# TPR 1% Yeom et al. 20000: 42.86, TPR 0.1% 13.33
# AUC Yeom et al. 20000: 97.88, Acc 93.33
# TPR 1% Yeom et al. 20000: 44.05, TPR 0.1% 11.25
# AUC Yeom et al. 25000: 98.17, Acc 93.84
# TPR 1% Yeom et al. 25000: 50.65, TPR 0.1% 16.71
# AUC Yeom et al. 25000: 98.57, Acc 95.29
# TPR 1% Yeom et al. 25000: 53.82, TPR 0.1% 15.10
# AUC Yeom et al. 25000: 98.13, Acc 93.99
# TPR 1% Yeom et al. 25000: 49.94, TPR 0.1% 13.87
# AUC Yeom et al. 25000: 97.98, Acc 93.41
# TPR 1% Yeom et al. 25000: 48.49, TPR 0.1% 16.72
# AUC Yeom et al. 25000: 98.48, Acc 94.77
# TPR 1% Yeom et al. 25000: 53.73, TPR 0.1% 17.22
# AUC Yeom et al. 25000: 98.04, Acc 93.58
# TPR 1% Yeom et al. 25000: 50.95, TPR 0.1% 15.02
# AUC Yeom et al. 30000: 98.57, Acc 94.70
# TPR 1% Yeom et al. 30000: 58.97, TPR 0.1% 20.71
# AUC Yeom et al. 30000: 98.77, Acc 95.66
# TPR 1% Yeom et al. 30000: 58.83, TPR 0.1% 14.67
# AUC Yeom et al. 30000: 98.26, Acc 94.18
# TPR 1% Yeom et al. 30000: 52.27, TPR 0.1% 17.60
# AUC Yeom et al. 30000: 98.67, Acc 95.29
# TPR 1% Yeom et al. 30000: 57.05, TPR 0.1% 20.89
# AUC Yeom et al. 30000: 98.46, Acc 94.54
# TPR 1% Yeom et al. 30000: 55.93, TPR 0.1% 19.48
# AUC Yeom et al. 30000: 98.87, Acc 95.98
# TPR 1% Yeom et al. 30000: 60.84, TPR 0.1% 17.83
# AUC Yeom et al. 35000: 98.84, Acc 95.44
# TPR 1% Yeom et al. 35000: 64.08, TPR 0.1% 19.00
# AUC Yeom et al. 35000: 99.04, Acc 96.39
# TPR 1% Yeom et al. 35000: 65.99, TPR 0.1% 21.65
# AUC Yeom et al. 35000: 98.90, Acc 95.80
# TPR 1% Yeom et al. 35000: 63.36, TPR 0.1% 20.92
# AUC Yeom et al. 35000: 98.83, Acc 95.39
# TPR 1% Yeom et al. 35000: 63.07, TPR 0.1% 21.17
# AUC Yeom et al. 35000: 98.72, Acc 95.00
# TPR 1% Yeom et al. 35000: 61.32, TPR 0.1% 23.65
# AUC Yeom et al. 35000: 98.93, Acc 95.91
# TPR 1% Yeom et al. 35000: 67.09, TPR 0.1% 19.53
# AUC Yeom et al. 45000: 99.39, Acc 96.66
# TPR 1% Yeom et al. 45000: 83.14, TPR 0.1% 26.63
# AUC Yeom et al. 45000: 99.38, Acc 96.79
# TPR 1% Yeom et al. 45000: 80.64, TPR 0.1% 40.61
# AUC Yeom et al. 45000: 99.32, Acc 96.64
# TPR 1% Yeom et al. 45000: 79.20, TPR 0.1% 40.62
# AUC Yeom et al. 45000: 99.38, Acc 96.82
# TPR 1% Yeom et al. 45000: 79.80, TPR 0.1% 34.64
# AUC Yeom et al. 45000: 99.21, Acc 96.55
# TPR 1% Yeom et al. 45000: 71.59, TPR 0.1% 40.05
# AUC Yeom et al. 45000: 99.31, Acc 96.78
# TPR 1% Yeom et al. 45000: 76.46, TPR 0.1% 35.37

# %%
import pandas as pd
import pickle

with open("./dataset_idxs/cifar100/cifar100_top_model_acc.pkl", "rb") as f:
    top_perf = pickle.load(f)

top_samples = {}
top_per = {}
top_per_mia = {}
top_mia = {}
top_mia_std = {}
top_bal_acc = {}

for info_type, score_func, _, method_name, augs, seeds in methods:
    top_samples[method_name] = []
    top_per[method_name] = []
    top_per_mia[method_name] = []
    top_mia[method_name] = []
    top_mia_std[method_name] = []
    top_bal_acc[method_name] = []

for idx, (info_type, score_func, _, method_name, augs, seeds) in enumerate(methods):
    for k, v in top_perf.items():
        if k not in accs_for_pu_trade_off['top']:
            continue
        top_samples[method_name].append(k)
        acc = np.array(v).mean()
        top_per[method_name].append(acc)
        accs_mia = np.array(accs_for_pu_trade_off['top'][k][idx][0])

        top_mia[method_name].append(accs_mia.mean())
        top_mia_std[method_name].append(accs_mia.std())
        # print(f"{method_name} {k}: {accs_mia}")
        top_per_mia[method_name].append(acc/(100 * accs_mia.mean()))
        top_bal_acc[method_name].append(np.array(bal_acc_for_pu_trade_off['top'][k][idx][0]).mean())

# %%
from scipy.interpolate import make_interp_spline

textwidth = 3.31314
aspect_ratio = 6/8
scale = 0.7
width = textwidth * scale
height = width * aspect_ratio
fig = plt.figure(figsize=(width, height))

colors = ['blue', 'red', 'orange', 'green']
for idx, (info_type, score_func, _, method_name, augs, seeds) in enumerate(methods):
    if 'NLL' not in method_name:
        continue
    
    df_top = pd.DataFrame({
        'samples': top_samples[method_name],
        'p_u_t': top_mia[method_name],
        'std': top_mia_std[method_name],
        'bal_acc': top_bal_acc[method_name]
    })

    
    df_top = df_top.sort_values(by='samples')
    
    # Calculate the upper and lower bounds for the shaded area
    upper_bound = df_top['p_u_t'].values + df_top['std'].values
    lower_bound = df_top['p_u_t'].values - df_top['std'].values


    plt.scatter(df_top['samples'].values / 50000, df_top['p_u_t'].values, color=colors[0], label=f'AUROC', alpha=0.5, s=2)
    plt.scatter(df_top['samples'].values / 50000, df_top['bal_acc'].values, color=colors[1], label=f'Balanced Accuracy', alpha=0.5, s=2)

    x = df_top['samples'].values / 50000
    # Generate x values for the polynomial line
    x_poly = np.linspace(min(x), max(x), 100)
    n = 2
    coefficients = np.polyfit(x, df_top['p_u_t'].values, n)
    polynomial = np.poly1d(coefficients)
    y_poly = polynomial(x_poly)

    # Plot the polynomial fit
    plt.plot(x_poly, y_poly, color=colors[0], alpha=0.5, ls='dashed', lw=1)
    x_poly = np.linspace(min(x), max(x), 100)
    n = 2
    coefficients = np.polyfit(x, df_top['bal_acc'].values, n)
    polynomial = np.poly1d(coefficients)
    y_poly = polynomial(x_poly)

    # Plot the polynomial fit
    plt.plot(x_poly, y_poly, color=colors[1], alpha=0.5, ls='dashed', lw=1)



# plt.plot(df_rand['samples'].values / 50000, np.ones_like(df_rand['samples'].values) * 0.5, color='gray', ls='dashed')
plt.ylabel("MIA AUROC / Bal. Acc")
plt.xlabel("Fraction of dataset used for training")
plt.legend()
plt.ylim(0.82, 1.0)
plt.show()
